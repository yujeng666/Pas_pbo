# %%
print("=== SOAL 1 ===")
a = 3
b = 2
c = 4
d = 5
e = 6
f = 1
g = 5
h = 6
i = 3
j = 2
k = 2
l = 1
m = 3
n = 1
o = 5
#dadu
Dadu = 6

jumlah = (a/Dadu)
print('no 1')
print(jumlah)
print('-----')
jumlah2 = (b/Dadu)
print('no 2')
print(jumlah2)
print('-----')
jumlah3 = (c/Dadu)
print('no 3')
print(jumlah3)
print('-----')
jumlah4 = (d/Dadu)
print('no 4')
print(jumlah4)
print('-----')
jumlah5 = (e/Dadu)
print('no 5')
print(jumlah5)
print('-----')
jumlah6 = (f/Dadu)
print('no 6')
print(jumlah6)
print('-----')
jumlah7 = (g/Dadu)
print('no 7')
print(jumlah7)
print('-----')
jumlah8 = (h/Dadu)
print('no 8')
print(jumlah8)
print('-----')
jumlah9 = (i/Dadu)
print('no 9')
print(jumlah9)
print('-----')
jumlah10 = (j/Dadu)
print('no 10')
print(jumlah10)
print('-----')
jumlah11 = (k/Dadu)
print('no 11')
print(jumlah11)
print('-----')
jumlah12 = (l/Dadu)
print('no 12')
print(jumlah12)
print('-----')
jumlah13 = (m/Dadu)
print('no 13')
print(jumlah13)
print('-----')
jumlah14 = (n/Dadu)
print('no 14')
print(jumlah14)
print('-----')
jumlah15 = (o/Dadu)
print('no 15')
print(jumlah15)
print('=====================')

total = (jumlah + jumlah2) + (jumlah3 + jumlah4) + (jumlah5 + jumlah6) + (jumlah7 + jumlah8) + (jumlah9 + jumlah10) + (jumlah11 + jumlah12) + (jumlah13 + jumlah14 )+ jumlah15
print("maka total probalitas nya adalah : " + str(total)) 

print('=====================================================')
Total = 3 + 2 + 4 + 1 + 3 + 2 + 2 + 1 + 3 + 1
print("maka total pelemparan dadu yang memiliki nilai < 5 adalah : " + str (Total))
# Out:
# === SOAL 1 ===
# no 1
# 0.5
# -----
# no 2
# 0.3333333333333333
# -----
# no 3
# 0.6666666666666666
# -----
# no 4
# 0.8333333333333334
# -----
# no 5
# 1.0
# -----
# no 6
# 0.16666666666666666
# -----
# no 7
# 0.8333333333333334
# -----
# no 8
# 1.0
# -----
# no 9
# 0.5
# -----
# no 10
# 0.3333333333333333
# -----
# no 11
# 0.3333333333333333
# -----
# no 12
# 0.16666666666666666
# -----
# no 13
# 0.5
# -----
# no 14
# 0.16666666666666666
# -----
# no 15
# 0.8333333333333334
# ...
# maka total probalitas nya adalah : 8.166666666666668
# ...
# maka total pelemparan dadu yang memiliki nilai < 5 adalah : 22

# %%
a = 9
b = 11
c = 3
d = 6
e = 2
f = 4
g = 9
h = 12
i = 10
j = 8
k = 2
l = 6
m = 3
n = 4  
o = 9
p = 8
q = 5
r = 6
s = 11
t = 10
#dadu
dadu = 12

jumlh = (a/dadu)
print('no 1')
print(jumlh)
print('-----')
jumlh2 = (b/dadu)
print('no 2')
print(jumlh2)
print('-----')
jumlh3 = (c/dadu)
print('no 3')
print(jumlh3)
print('-----')
jumlh4 = (d/dadu)
print('no 4')
print(jumlh4)
print('-----')
jumlh5 = (e/dadu)
print('no 5')
print(jumlh5)
print('-----')
jumlh6 = (f/dadu)
print('no 6')
print(jumlh6)
print('-----')
jumlh7 = (g/dadu)
print('no 7')
print(jumlh7)
print('-----')
jumlh8 = (h/dadu)
print('no 8')
print(jumlh8)
print('-----')
jumlh9 = (i/dadu)
print('no 9')
print(jumlh9)
print('-----')
jumlh10 = (j/dadu)
print('no 10')
print(jumlh10)
print('-----')
jumlh11 = (k/dadu)
print('no 11')
print(jumlh11)
print('-----')
jumlh12 = (l/dadu)
print('no 12')
print(jumlh12)
print('-----')
jumlh13 = (m/dadu)
print('no 13')
print(jumlh13)
print('-----')
jumlh14 = (n/dadu)
print('no 14')
print(jumlh14)
print('-----')
jumlh15 = (o/dadu)
print('no 15')
print(jumlh15)
print('-----')
jumlh16 = (p/dadu)
print('no 16')
print(jumlh10)
print('-----')
jumlh17 = (q/dadu)
print('no 17')
print(jumlh17)
print('-----')
jumlh18 = (r/dadu)
print('no 18')
print(jumlh18)
print('-----')
jumlh19 = (s/dadu)
print('no 19')
print(jumlh19)
print('-----')
jumlh20 = (t/dadu)
print('no 20')
print(jumlh20)
print('=====================')
ttl = (jumlh + jumlh2) + (jumlh3 + jumlh4) + (jumlh5 + jumlh6) + (jumlh7 + jumlh8) + (jumlh9 + jumlh10) + (jumlh11 + jumlh12) + (jumlh13 + jumlh14) + (jumlh15 +
jumlh16) + (jumlh17 + jumlh18) + (jumlh19 + jumlh20) 
print("maka total probalitas nya adalah : " + str(ttl)) 

print('=====================================================')
jml = (6/6) +(2/6) + (4/6) + (12/6) + (10/6) + (8/6) + (2/6) + (6/6) + (4/6) + (8/6) + (6/6) + (10/6)
print('Total pelemparan dadu yang memiliki nilai genap adalah : ' + str(jml))
# Out:
# no 1
# 0.75
# -----
# no 2
# 0.9166666666666666
# -----
# no 3
# 0.25
# -----
# no 4
# 0.5
# -----
# no 5
# 0.16666666666666666
# -----
# no 6
# 0.3333333333333333
# -----
# no 7
# 0.75
# -----
# no 8
# 1.0
# -----
# no 9
# 0.8333333333333334
# -----
# no 10
# 0.6666666666666666
# -----
# no 11
# 0.16666666666666666
# -----
# no 12
# 0.5
# -----
# no 13
# 0.25
# -----
# no 14
# 0.3333333333333333
# -----
# no 15
# 0.75
# -----
# no 16
# 0.6666666666666666
# -----
# no 17
# 0.4166666666666667
# -----
# no 18
# 0.5
# -----
# no 19
# 0.9166666666666666
# -----
# no 20
# 0.8333333333333334
# ...
# maka total probalitas nya adalah : 11.499999999999998
# ...
# Total pelemparan dadu yang memiliki nilai genap adalah : 12.999999999999998

# %%
print("=== SOAL 2 ===")
print('Minggu ke-1')
m1 = 6560860 + 5950850 + 12685900 + 5768500 + 2989000
print('maka jumlah total minggu ke-1 adalah : Rp.' + str(m1)) 
print('Minggu ke-2')
m2 = 8782150 + 6620000 + 5128750 + 5217300 + 4820600
print('maka jumlah total minggu ke-2 adalah : Rp.' + str(m2)) 
print('Minggu ke-3')
m3 = 8130940 + 2940650 + 3488200 + 6930540 + 4319260
print('maka jumlah total minggu ke-3 adalah : Rp.' + str(m3)) 
print('Minggu ke-4')
m4 = 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print('maka jumlah total minggu ke-4 adalah : Rp.' + str(m4)) 

#menampilkan grafik
import matplotlib.pyplot as plt

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
minggu = ['ke-1', 'ke-2','ke-3', 'ke-4', ]
total = [33955110,30568800,25809590,32592290,]
plt.title("Data pendapatan perminggu")
plt.bar(minggu, total,)
plt.show()

fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
minggu = ['ke-1', 'ke-2','ke-3', 'ke-4', ]
total = [33955110,30568800,25809590,32592290,]
plt.title("Data pendapatan perminggu")
plt.scatter(minggu, total,)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0, 0, 1,1])
ax.axis('equal')
minggu = ['ke-1', 'ke-2','ke-3', 'ke-4', ]
total = [33955110,30568800,25809590,32592290,]

ax.pie(total,labels=minggu,autopct='%1.2f%%',)
plt.title("Data pendapatan perminggu")
plt.show()
print('=====================================================')
print('=====================================================')
print('no2')
print('buah')
buah = ( 6560860 + 8782150 + 8130940 + 12849100 ) / ( 386 + 454 + 599 + 867 )
print('rata rata harga buah dari minggu 1 sd 4 adalah : '+str(buah))
print('=====================================================')
print('Keperluan dapur')
dapur = (5950850 + 6620000 + 2940650 + 5752200 ) / ( 752 + 781 + 338 + 512 )
print('rata rata harga keperluan dari minggu 1 sd 4 adalah : '+str(dapur))
print('=====================================================')
print('snack / makanan')
snack = (12685900 + 5128750 + 3488200 + 5128400) / ( 1203 + 634 + 442 + 650)
print('rata rata harga makanan dari minggu 1 sd 4 adalah : '+str(snack))
print('=====================================================')
print('Keperluan mandi')
mandi = (5768500 + 5217300 + 6930540 + 3880490 ) / ( 715 + 659 + 872 + 492 )
print('rata rata harga keperluan mandi dari minggu 1 sd 4 adalah : '+str(mandi))
print('=====================================================')
print('perlengkapan rumah tangga')
rumah = (2989000 + 4820600 +4319260 + 4982100 ) / ( 289 + 411 + 390 + 488 )
print('rata rata harga perlengkapan rumah tangga dari minggu 1 sd 4 adalah : '+str(rumah))
print('=====================================================')
print('=====================================================')
print('no3')
print('Minggu ke-1')
A = (810 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-2')
A = (814 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-3')
A = (865 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-4')
A = (1073 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('=====================================================')
print('=====================================================')

print('no4')
print('Minggu ke-1')
A = (33955110 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-2')
A = (30568800 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-3')
A = (25809590 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('Minggu ke-4')
A = (32592290 / 2)
B = (A / 5)
print('jumlah pengungjung di hari biasa adalah : '+str(B))
C = (A / c) 
print('jumlah pengungjung di hari weekend adalah : '+str(C))

print('=====================================================')
print('=====================================================')
print('no5')
print('buah')
buah = 386 + 454 + 599 + 867
print('total penjuan buah : ' + str(buah))
buah2 = 6560860 + 8782150 + 8130940 + 12849100
print('total pendapatan buah : ' + str(buah2))
print('dapur')
dapur = 752 + 781 + 338 + 512
print('total penjuan buah : ' + str(dapur))
dapur2 = 5950850 +6620000 +2940650 +5752200
print('total pendapatan buah : ' + str(dapur2))
print('buah')
snack = 1203 +634 + 442 + 650
print('total penjuan buah : ' + str(snack))
snack2 = 12685900  +5128750  +3488200 +5128400 
print('total pendapatan buah : ' + str(snack2))
print('buah')
mandi =715 +659 + 872 + 492
print('total penjuan buah : ' + str(mandi))
mandi2 = 5768500 +5217300 +6930540 +3880490 
print('total pendapatan buah : ' + str(mandi2))
print('buah')
rumah = 289 + 411 + 390 + 488
print('total penjuan buah : ' + str(rumah))
rumah2 =5768500 +5217300 +6930540 +3880490
print('total pendapatan buah : ' + str(rumah2))
# Out:
# === SOAL 2 ===
# Minggu ke-1
# maka jumlah total minggu ke-1 adalah : Rp.33955110
# Minggu ke-2
# maka jumlah total minggu ke-2 adalah : Rp.30568800
# Minggu ke-3
# maka jumlah total minggu ke-3 adalah : Rp.25809590
# Minggu ke-4
# maka jumlah total minggu ke-4 adalah : Rp.32592290
# ...
# no2
# buah
# rata rata harga buah dari minggu 1 sd 4 adalah : 15751.539462272332
# ...
# Keperluan dapur
# rata rata harga keperluan dari minggu 1 sd 4 adalah : 8923.08015107008
# ...
# snack / makanan
# rata rata harga makanan dari minggu 1 sd 4 adalah : 9023.984294981223
# ...
# Keperluan mandi
# rata rata harga keperluan mandi dari minggu 1 sd 4 adalah : 7960.858290723156
# ...
# perlengkapan rumah tangga
# rata rata harga perlengkapan rumah tangga dari minggu 1 sd 4 adalah : 10843.447401774398
# ...
# no3
# Minggu ke-1
# jumlah pengungjung di hari biasa adalah : 81.0
# jumlah pengungjung di hari weekend adalah : 202.5
# Minggu ke-2
# jumlah pengungjung di hari biasa adalah : 81.4
# ...
